# %%
from models.omnimodels import OmniModels
from models.omnidatasets import OmniDatasets

# %%
omni = OmniModels()
ds = OmniDatasets()

# %%
omni.ontology.wp.api_url_for_entity('cases')
# Out:
# 'https://ontologia.eximia.co/wp-json/wp/v2/cases'

# %%
d = ds.timesheets.get_last_six_weeks()

# %%
d.data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1042 entries, 0 to 1041
# Data columns (total 31 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Id                  1042 non-null   int64
#  1   CreatedAt           1042 non-null   datetime64[ns]
#  2   Date                1042 non-null   object
#  3   UserId              1042 non-null   int64
#  4   Time                1042 non-null   int64
#  5   ProjectId           1042 non-null   object
#  6   IsSquad             1042 non-null   bool
#  7   IsEximiaco          1042 non-null   bool
#  8   Week                1042 non-null   object
#  9   TimeInHs            1042 non-null   float64
#  10  Kind                1042 non-null   object
#  11  CreatedAtWeek       1042 non-null   object
#  12  Correctness         1042 non-null   object
#  13  IsLte               1042 non-null   bool
#  14  DayOfWeek           1042 non-null   object
# ...

# %%
d.data
# Out:
#              Id           CreatedAt        Date   UserId   Time  \
# 0     208558764 2024-08-13 20:38:13  2024-08-16  1196046  28800
# 1     208427642 2024-08-12 18:39:38  2024-08-16   925843  28800
# 2     208381443 2024-08-12 13:30:11  2024-08-16  1075241  28800
# 3     208373977 2024-08-12 12:42:31  2024-08-16  1040765  28800
# 4     208370115 2024-08-12 12:11:54  2024-08-16  1130379  28800
# ...         ...                 ...         ...      ...    ...
# 1037  205174166 2024-07-08 13:05:29  2024-07-08   925841   3600
# 1038  205167039 2024-07-08 12:14:32  2024-07-08   925831  28800
# 1039  205166246 2024-07-08 12:07:44  2024-07-08  1040765   3600
# 1040  205166243 2024-07-08 12:07:43  2024-07-08  1040765  28800
# 1041  205117543 2024-07-08 02:53:11  2024-07-07  1340427  15120
#
#                ProjectId  IsSquad  IsEximiaco           Week  TimeInHs  ...  \
# 0     ev:225279830118274     True       False  11/08 - 17/08       8.0  ...
# ...

# %%
d.filter_by('AccountManagerName', is_in=['Gustavo Azevedo', 'Gustavo de Paula']).data
# Out:
#              Id           CreatedAt        Date   UserId   Time  \
# 0     208558764 2024-08-13 20:38:13  2024-08-16  1196046  28800
# 1     208427642 2024-08-12 18:39:38  2024-08-16   925843  28800
# 2     208381443 2024-08-12 13:30:11  2024-08-16  1075241  28800
# 3     208373977 2024-08-12 12:42:31  2024-08-16  1040765  28800
# 4     208370115 2024-08-12 12:11:54  2024-08-16  1130379  28800
# ...         ...                 ...         ...      ...    ...
# 1037  205174166 2024-07-08 13:05:29  2024-07-08   925841   3600
# 1038  205167039 2024-07-08 12:14:32  2024-07-08   925831  28800
# 1039  205166246 2024-07-08 12:07:44  2024-07-08  1040765   3600
# 1040  205166243 2024-07-08 12:07:43  2024-07-08  1040765  28800
# 1041  205117543 2024-07-08 02:53:11  2024-07-07  1340427  15120
#
#                ProjectId  IsSquad  IsEximiaco           Week  TimeInHs  ...  \
# 0     ev:225279830118274     True       False  11/08 - 17/08       8.0  ...
# ...

# %%
from markdown import markdown
markdown_content = """
# Slide 1
Conteúdo do primeiro slide.

---

# Slide 2
Conteúdo do segundo slide.

---

# Slide 3
Conteúdo do terceiro slide.
    """

slides_html = markdown(markdown_content, extensions=['markdown.extensions.extra'])

# %%
slides_html
# Out:
# '<h1>Slide 1</h1>\n<p>Conteúdo do primeiro slide.</p>\n<hr />\n<h1>Slide 2</h1>\n<p>Conteúdo do segundo slide.</p>\n<hr />\n<h1>Slide 3</h1>\n<p>Conteúdo do terceiro slide.</p>'
